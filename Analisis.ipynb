# %% [markdown]
# <a href="https://colab.research.google.com/github/joelmoraesDev/joelmoraesDev/blob/main/Analisis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# esto es una prueba para github
print("GitHub")
# Out:
# GitHub
